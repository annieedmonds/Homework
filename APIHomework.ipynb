# %% [markdown]
# <a href="https://colab.research.google.com/github/annieedmonds/Homework/blob/main/APIHomework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd

# %%
ticker_symbol = input()

api_key = "p2jDtVCw7T1Q8sCFQ2DGM73Y5MvOSLSO8yQBcdTi"

url = f"https://yfapi.net/v6/finance/quote?region=US&lang=en&symbols={ticker_symbol}"


headers = {
    'x-api-key': api_key
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    stock_data = response.json()


    if 'quoteResponse' in stock_data and stock_data['quoteResponse']['result']:
        stock_info = stock_data['quoteResponse']['result'][0]

        ticker_name = stock_info.get('symbol', 'N/A')
        full_name = stock_info.get('longName', 'N/A')
        current_price = stock_info.get('regularMarketPrice', 'N/A')
        target_mean_price = stock_info.get('targetMeanPrice', 'N/A')
        week_52_high = stock_info.get('fiftyTwoWeekHigh', 'N/A')
        week_52_low = stock_info.get('fiftyTwoWeekLow', 'N/A')

        print(f"Ticker Name: {ticker_name}")
        print(f"Full Name: {full_name}")
        print(f"Current Market Price: {current_price}")
        print(f"Target Mean Price: {target_mean_price}")
        print(f"52-Week High: {week_52_high}")
        print(f"52-Week Low: {week_52_low}")
    else:
        print("No stock data found for the given symbol.")
else:
    print(f"Failed to retrieve data: {response.status_code}")


#ouput 5 of the current trending stock
url = "https://yfapi.net/v1/finance/trending/US"
headers = {
    'x-api-key': api_key
}
response = requests.get(url, headers=headers)
if response.status_code == 200:
  trending_data = response.json()

  if 'finance' in trending_data and 'result' in trending_data['finance'] and trending_data['finance']['result']:
    trending_stocks = trending_data['finance']['result'][0]['quotes']
    print("\n5 Current Trending Stocks:")
    for stock in trending_stocks[:5]:
      print(f"Ticker: {stock.get('symbol', 'N/A')}")
  else:
    print("No trending stock data found.")
else:
  print(f"Failed to retrieve data: {response.status_code}")
# Out:
# aapl
# Ticker Name: AAPL
# Full Name: Apple Inc.
# Current Market Price: 227.79
# Target Mean Price: N/A
# 52-Week High: 237.23
# 52-Week Low: 164.08
#
# 5 Current Trending Stocks:
# Ticker: NIO
# Ticker: IONQ
# Ticker: RKLB
# Ticker: LULU
# Ticker: COST

# %%
#put into a Dataframe and then store that to a CSV file
df_trending_stocks= pd.DataFrame(trending_stocks)
df_stock_data = pd.DataFrame(stock_data)
df_joined = pd.concat([df_stock_data, df_trending_stocks], axis=1)
df_joined.to_csv('stock_data.csv', index=False)
df_joined
# Out:
#                                             quoteResponse  symbol
# error                                                None     NaN
# result  [{'language': 'en-US', 'region': 'US', 'quoteT...     NaN
# 0                                                     NaN     NIO
# 1                                                     NaN    IONQ
# 2                                                     NaN    RKLB
# 3                                                     NaN    LULU
# 4                                                     NaN    COST
# 5                                                     NaN    TSLA
# 6                                                     NaN    ASTS
# 7                                                     NaN    UXIN
# 8                                                     NaN    ACHC
# 9                                                     NaN  PAY.TO
# 10                                                    NaN     TSM
# ...
